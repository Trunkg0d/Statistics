# %% [markdown]
# ### A Step-by-Step Guide to the Data Analysis Process
# **Defining the question.**
#
# **Collecting the data.**
#
# **Cleaning the data.**
#
# **Analyzing the data.**
#
# **Sharing your results.**
#
# **Embracing failure.**
#
# **Summary**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DelayedFlights.csv")
df
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unnamed: 0       Year         Month    DayofMonth     DayOfWeek  \
# count  1.936758e+06  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06
# mean   3.341651e+06     2008.0  6.111106e+00  1.575347e+01  3.984827e+00
# std    2.066065e+06        0.0  3.482546e+00  8.776272e+00  1.995966e+00
# min    0.000000e+00     2008.0  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.517452e+06     2008.0  3.000000e+00  8.000000e+00  2.000000e+00
# 50%    3.242558e+06     2008.0  6.000000e+00  1.600000e+01  4.000000e+00
# 75%    4.972467e+06     2008.0  9.000000e+00  2.300000e+01  6.000000e+00
# max    7.009727e+06     2008.0  1.200000e+01  3.100000e+01  7.000000e+00
#
#             DepTime    CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.936758e+06  1.936758e+06  1.929648e+06  1.936758e+06  1.936758e+06
# mean   1.518534e+03  1.467473e+03  1.610141e+03  1.634225e+03  2.184263e+03
# std    4.504853e+02  4.247668e+02  5.481781e+02  4.646347e+02  1.944702e+03
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 4                 5  2008      1           3          4   1940.0        1915
# 6                10  2008      1           3          4    706.0         700
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936739     7009646  2008     12          13          6   1100.0        1045
# 1936740     7009652  2008     12          13          6   1200.0        1150
# 1936750     7009702  2008     12          13          6   1531.0        1522
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
#Check type of columns

# %%
#Fill NaN in columns CarrierDelay
df["CarrierDelay"].dtypes
df["CarrierDelay"] = df["CarrierDelay"].fillna(df["CarrierDelay"].mean())

# %%
#Fill NaN in columns WeatherDelay
df["WeatherDelay"].dtypes
df["WeatherDelay"] = df["WeatherDelay"].fillna(df["WeatherDelay"].mean())

# %%
#Fill NaN in columns NASDelay
df["NASDelay"].dtypes
df["NASDelay"] = df["NASDelay"].fillna(df["NASDelay"].mean())

# %%
#Fill NaN in columns SecurityDelay
df["SecurityDelay"].dtypes
df["SecurityDelay"] = df["SecurityDelay"].fillna(df["SecurityDelay"].mean())

# %%
#Fill NaN in columns LateAircraftDelay
df["LateAircraftDelay"].dtypes
df["LateAircraftDelay"] = df["LateAircraftDelay"].fillna(df["LateAircraftDelay"].mean())

# %%
df[df.isna().any(axis=1)]
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 1280           1763  2008      1           3          4    922.0         915
# 1372           1911  2008      1           3          4   2325.0        1900
# 1776           2651  2008      1           4          5   1949.0        1905
# 1831           2726  2008      1           4          5    737.0         705
# 2244           3672  2008      1           4          5   1849.0        1630
# ...             ...   ...    ...         ...        ...      ...         ...
# 1935651     7006289  2008     12          10          3   1459.0        1447
# 1935716     7006401  2008     12          11          4   1355.0        1106
# 1935876     7006809  2008     12          11          4   1026.0         955
# 1935978     7007034  2008     12          11          4   1527.0        1520
# 1936470     7008584  2008     12          12          5    703.0         630
#
# ...

# %%
df["ArrTime"] = df["ArrTime"].fillna(df["ArrTime"].mean())
df["TaxiIn"] = df["TaxiIn"].fillna(df["TaxiIn"].mean())
df["TaxiOut"] = df["TaxiOut"].fillna(df["TaxiOut"].mean())

# %%
df[df.isna()]
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0               NaN   NaN    NaN         NaN        NaN      NaN         NaN
# 1               NaN   NaN    NaN         NaN        NaN      NaN         NaN
# 2               NaN   NaN    NaN         NaN        NaN      NaN         NaN
# 3               NaN   NaN    NaN         NaN        NaN      NaN         NaN
# 4               NaN   NaN    NaN         NaN        NaN      NaN         NaN
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753         NaN   NaN    NaN         NaN        NaN      NaN         NaN
# 1936754         NaN   NaN    NaN         NaN        NaN      NaN         NaN
# 1936755         NaN   NaN    NaN         NaN        NaN      NaN         NaN
# 1936756         NaN   NaN    NaN         NaN        NaN      NaN         NaN
# 1936757         NaN   NaN    NaN         NaN        NaN      NaN         NaN
#
# ...
